# %%
# %run parse_email_active_users.py
email_addr='anna.chystiakova@oracle.com'
email_pswd='!Tssa2016'
email_path='INBOX/'
subject_expr='Weekly_active_users_for_all_companies.'
source_path="/home/annac/"
leter_path=source_path+'emails/'
get_week_act_users(email_addr, email_pswd, email_path, subject_expr,leter_path)
# Out:
# login to E-mail : OK

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Jun 30 13:54:02 2016

@author: anna
"""
import sys
sys.path.append('/usr/local/lib/python2.7/dist-packages/')

import pandas as pd
import numpy as np
import datetime
from os import listdir
from os.path import isfile, join
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import logging
import IPython
from IPython.display import display, HTML
# %run load_sar_data.py
# %run parse_sar_data.py
# %run load_forecast.py
# %run plot_class_data.py

# %%
#Input data
#Source path for local data storage
#The path contains the tmp, emails, results subfolders
source_path="/Users/annachystiakova/Documents/sar-parse/"#/home/annac/"
#Path to store sar files with parsed data and figures
path="/Users/annachystiakova/Documents/Capacity/sar_analysis/sar_data/"
#Email data 
email_addr='anna.chystiakova@oracle.com'
email_pswd='!Tssa2016'
email_path='INBOX/'
subject_expr='Weekly_active_users_for_all_companies.'
leter_path=source_path+'emails/'
#Data to access the remote hosts
#Username
user="annac"
#Pasword for remote hosts
password="ITssa2016"
#Start date of analysis
start="2016-07-16 00:00:00 AM"
#End date of analysis
end="2016-07-26 00:00:00 AM"

# %% [markdown]
# Prepare data about hosts, Groups, Classes from CMDB with corrections

# %%
def complete_data(data, col_origin):
    data=data[col_origin]
    data.columns=['Group', 'server']
    gr=""
    for i in data.index:
        if type(data['Group'].values[i])==float and np.isnan(data['Group'].values[i]):
            data['Group'][i]=gr
        else:
            gr=data['Group'][i]
    data=data[~data.Group.isin(['none', 'no information'])]
    return data

D_add=pd.read_excel(source_path+"VM_data.xls", sheetname='Add_to_CMDB')
D_add=complete_data(D_add,col_origin=["Group", "summary"])
D_remove=pd.read_excel(source_path+"VM_data.xls", sheetname='Remove_from_CMDB')
D_remove=complete_data(D_remove,col_origin=["Server Group", "Server Name"])
D=pd.read_excel(source_path+"VM_data.xls", sheetname='Prod_CMDB')
D=complete_data(D,col_origin=["Group", "Server"])
D_SG5=pd.read_excel(source_path+"VM_data.xls", sheetname='SG5_hosts')
D_SG5=complete_data(D_SG5,col_origin=["Group", "Server"])

D=D[~D.server.isin(D_remove.server.values)]
D=D.append(D_add)
D=D.append(D_SG5)
D=D.drop_duplicates()
if D.server.duplicated().any()==True:
    print('There are duplicated Server names!!!')
D_host_struct=D
All_Groups=D_host_struct.Group.unique()
All_Groups_PROD=[x for  x in All_Groups if 'PROD' in x]
All_Groups_TEST=[x for  x in All_Groups if 'TEST' in x]
All_Groups_SHARED=[x for  x in All_Groups if 'SHARED' in x]
Classes=[x.split("-PROD-")[0] for x in All_Groups_PROD]
Classes=pd.unique(Classes)
# Out:
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# To analyse the capacity based on ugrade process
# the "Companies_16_2.xlsx" contains the data
# for upgrade with appropriate dates
# The part of code below defines the number of active users and dates per upgrade wave.

# %%
import xlrd
import warnings
import calendar
xls = xlrd.open_workbook("Companies_16_2.xlsx", on_demand=True)
#print([x.encode('utf8') for x in xls.sheet_names()])
waves=[x for x in xls.sheet_names() if x.encode('utf8').startswith('Wave')]
Input_D=pd.DataFrame()


for W in waves:
    CMDB_Companies=pd.read_excel("Companies_16_2.xlsx", sheetname=W)
    CMDB_Companies=CMDB_Companies[['Instance ID','Instance Name','BE Master','Version', 'Date upgrade']]
    CMDB_Companies.rename(columns={'Instance ID': 'Instance ID', 'Instance Name': 'Company', 'BE Master':'BE Master','Version':'Version', 'Date upgrade':'Date upgrade'}, inplace=True)
    CMDB_Companies['Company'].replace([u'musmrs',u'vm2', u'amx-res-cenam', u'cbv', u'vodafone', u'amx-res-co',u'lm',u'kiercorporate'],[ u'mus',u'virginmedia', u'amx-cenam', u'cablevision', u'vodafone-spain',u'amx-colombia', u'liberty',u'kierutilities'],inplace=True)

    start=CMDB_Companies['Date upgrade'].values[0]
    print('Start is ',str(start)[:10])
    year=datetime.datetime.strptime(str(start)[:10],"%Y-%m-%d").year
    month=datetime.datetime.strptime(str(start)[:10],"%Y-%m-%d").month
    Month_bil=pd.read_excel(source_path+"Active_users_for_all_companies.xlsx", sheetname=str(year))
    Month_bil=Month_bil.dropna(axis=1, how='all')
    Month_bil=(Month_bil[0:Month_bil.loc[Month_bil['Company'] == 'INACTIVE'].index.tolist()[0]])
    MD=dict((v,k) for k,v in enumerate(calendar.month_abbr))
    Month_bil.columns=[MD[x] if x!='Company' else x for x in Month_bil.columns ]
    Month_bil=Month_bil[['Company']+[x for x in Month_bil.columns if x!='Company' and x<=month]]
    Month_bil['Company']=Month_bil['Company'].str.lower()
    MM=max([x for x in Month_bil.columns if x!='Company'])
    Month_bil=Month_bil[['Company', MM]]
    Month_bil=Month_bil.dropna(axis=0, how='any')
    Comp_Users=CMDB_Companies.merge(Month_bil, on=['Company'])
    DIF=(list(set(CMDB_Companies.Company)-set(Month_bil.Company)))

    if (len(DIF)>0):
        msg='Companies not found in billing !!!',','.join(DIF)
        #warnings.warn(msg)
        print(msg)
    #print(list(set(CMDB_Companies.Company)-set(Month_bil.Company)))
    MIA_users_16_2=Comp_Users[Comp_Users['BE Master'].str.contains('ed1')]
    MIA_users_16_2=MIA_users_16_2[MIA_users_16_2['Version'].str.contains('platform-16.2.')]
    print('Sum number of users in ED1 version 16.2 in ', str(W))
    print(MIA_users_16_2[MM].sum())

    MAD_users_16_2=Comp_Users[Comp_Users['BE Master'].str.contains('ed5')]
    MAD_users_16_2=MAD_users_16_2[MAD_users_16_2['Version'].str.contains('platform-16.2.')]
    print('Sum number of users in ED5 version 16.2 in ', str(W))
    print(MAD_users_16_2[MM].sum())
    r={'Start':start,'MIA_users':MIA_users_16_2[MM].sum(), 'MAD_users':MAD_users_16_2[MM].sum()}
    Input_D=Input_D.append(pd.DataFrame(r, index=[start]))

Input_D
#CMDB=pd.read_excel(source_path+"Companies_16_2.xlsx", sheetname='All_CMDB')
# Out:
# ('Start is ', '2016-05-20')
# ('Companies not found in billing !!!', u'sg1-miami,dnvgl,yahsat')
# ('Sum number of users in ED1 version 16.2 in ', 'Wave1')
# 14387.0
# ('Sum number of users in ED5 version 16.2 in ', 'Wave1')
# 2030.0
# ('Start is ', '2016-07-26')
# ('Companies not found in billing !!!', u'sg1-miami,manchi,rinnai')
# ('Sum number of users in ED1 version 16.2 in ', 'Wave2')
# 25008.0
# ('Sum number of users in ED5 version 16.2 in ', 'Wave2')
# 13916.0
#             MAD_users  MIA_users      Start
# 2016-05-20     2030.0    14387.0 2016-05-20
# 2016-07-26    13916.0    25008.0 2016-07-26

# %%
print end

print start
path
# Out:
# 2016-08-02 17:31:56.974776
# 2016-07-26 00:00:00
# '/Users/annachystiakova/Documents/Capacity/sar_analysis/sar_data/'

# %%
def get_analysis_upgrades(D,Sclass, start, end):
    NET='PROD'

    Ds=D[D.Group.str.contains(NET)]
    Ds=Ds[Ds.Group.str.contains(Sclass)]
    DF=pd.DataFrame()
    print('Analysis for Class of hosts '+Sclass)
    for host in Ds['server']:
        print host
        r=get_host_data (host, user, password)
        if r==0:
            continue
        get_resource_tables(path+host)
        #if host in os.listdir(path):
        R=forecast_on_sar(host, user, path=path, start=start, end=end, plot_clust=False)
        DF=DF.append(R)
        #else:
        #    print('The host data is empty or host id FreeBSD OS')

    if DF.shape[0]>0:

        DFR_CPU=pd.DataFrame()
        DFR_RAM=pd.DataFrame()
        for h in DF.index.unique():
            d=DF.loc[h]
            d=d[d['Param'].str.contains('real_used')]
            d=d[d.Used==max(d.Used)]
            DFR_RAM=DFR_RAM.append(d)
            d=DF.loc[h]
            d=d[d['Param']=='used_cpu']
            DFR_CPU=DFR_CPU.append(d)
        DFR_RAM['server']=DFR_RAM.index.values
        DFR_CPU['server']=DFR_CPU.index.values
        DFR_RAM['Available']=[np.round(np.float16(DFR_RAM.loc[i]['Capacity'])-np.float16(DFR_RAM.loc[i]['Used']),2) \
                              for i in DFR_RAM.index]
        DFR_CPU['Available']=[np.round(np.float16(DFR_CPU.loc[i]['Capacity'])*100-np.float16(DFR_CPU.loc[i]['Used'].replace(' %', '')),2) \
                              for i in DFR_CPU.index]
        DFR_CPU=pd.merge(DFR_CPU, D)
        DFR_RAM=pd.merge(DFR_RAM, D)
        F=get_resource_data(Sclass,DFR_RAM=DFR_RAM, DFR_CPU=DFR_CPU)

        DFR_CPU_d=DFR_CPU[['Capacity', 'Details', 'Resource','Used', 'server', 'Available']]
        DFR_CPU_d.columns=['Capacity_cpu', 'Details_cpu', 'Resource','Used_cpu', 'server', 'Available_cpu']
        DFR_RAM_d=DFR_RAM[['Capacity', 'Details', 'Resource','Used', 'server', 'Available', 'Group']]
        DFR_RAM_d.columns=['Capacity_mem', 'Details_mem', 'Resource','Used_mem', 'server', 'Available_mem', 'Group']
        D=DFR_CPU_d.merge(DFR_RAM_d, on='server')
        RES=pd.DataFrame()
        for G in D.Group.unique():
            d=D[D.Group==G]
            d['util_mem']=100*d['Used_mem']/d['Capacity_mem']
            d['util_cpu']=[np.float16(x.replace(' %','')) for x in d['Used_cpu']]

            min_util_mem=min(d['util_mem'])
            max_util_mem=max(d['util_mem'])
            avg_util_mem=100*(sum(d['Used_mem'])/sum(d['Capacity_mem']))
            sum_utilized_mem=sum(d['Used_mem'])
            s=d['Capacity_mem'].unique()
            mem_per_fost=','.join(str(x) for x in s )

            min_util_cpu=min(d['util_cpu'])
            max_util_cpu=max(d['util_cpu'])
            avg_util_cpu=100*(sum(d['util_cpu'])/sum(100*d['Capacity_cpu']))
            sum_utilized_cpu=sum(d['util_cpu'])
            s1=d['Capacity_cpu'].unique()
            cpu_per_fost=','.join(str(x) for x in s1 )
            RES=RES.append({'Server_class':G, 'Number_of_hosts':d.shape[0],'Mem_min_utilized':min_util_mem, \
                            'Mem_max_utilized':max_util_mem, 'Mem_avg_clust':avg_util_mem, 'Config_mem':mem_per_fost,\
                            'Mem_Sum_utilized': sum_utilized_mem,\
                           'CPU_min_utilized':min_util_cpu, \
                            'CPU_max_utilized':max_util_cpu, 'CPU_avg_clust':avg_util_cpu, 'Config_cpu':cpu_per_fost,\
                            'CPU_Sum_utilized': sum_utilized_cpu},ignore_index=True)
        plot_data(RES)
        RES['Users']=[np.nan]*RES.shape[0]
        for i in RES.index:
            if 'ED1' in RES.ix[i]['Server_class']:
                RES.loc[i,'Users']=Input_D.MIA_users[0]
            elif 'ED5' in RES.ix[i]['Server_class']:
                RES.loc[i,'Users']=Input_D.MAD_users[0]
        RES=RES.dropna(axis=0)

        RES.to_csv(path+Sclass+str(datetime.datetime.now())+".csv")

start=str(Input_D.index[1])
end=str(datetime.datetime.today())
for Sclass in Classes:
    get_analysis_upgrades(D_host_struct, Sclass, start, end)
# Out:
# Analysis for Class of hosts ADM-AIU
# aiu101.adm.prod.ed1
# aiu101.adm.prod.ed2
# aiu101.adm.prod.ed5
# ADM-AIU-PROD-ED1-101
# <string>:381: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-AIU-PROD-ED1-101       1   Memory           8.0       7.0
# 1  ADM-AIU-PROD-ED1-101       1      CPU         400.0     166.5
# Summary CPU
# Used 41.625 %
# Summary RAM
# Used 87.5 %
# ADM-AIU-PROD-ED2-101
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-AIU-PROD-ED2-101       1   Memory           8.0      4.00
# 1  ADM-AIU-PROD-ED2-101       1      CPU         400.0    136.25
# Summary CPU
# Used 34.0625 %
# Summary RAM
# Used 50.0 %
# ADM-AIU-PROD-ED5-101
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-AIU-PROD-ED5-101       1   Memory           8.0   7.00000
# 1  ADM-AIU-PROD-ED5-101       1      CPU         400.0  30.09375
# Summary CPU
# Used 7.5234375 %
# Summary RAM
# Used 87.5 %
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:49: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:50: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Analysis for Class of hosts ADM-BE
# be001.adm.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.adm.prod.ed1
# The host data is empty or host id FreeBSD OS
# BE001.ADM.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE002.ADM.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ADM-CFE
# cfe101.adm.prod.ed1
# cfe101.adm.prod.ed2
# cfe101.adm.prod.ed5
# ADM-CFE-PROD-ED1-101
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-CFE-PROD-ED1-101       1   Memory           8.0       6.0
# 1  ADM-CFE-PROD-ED1-101       1      CPU         400.0      67.0
# Summary CPU
# Used 16.75 %
# Summary RAM
# Used 75.0 %
# ADM-CFE-PROD-ED2-101
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-CFE-PROD-ED2-101       1   Memory           8.0       5.0
# 1  ADM-CFE-PROD-ED2-101       1      CPU         400.0      34.0
# Summary CPU
# Used 8.5 %
# Summary RAM
# Used 62.5 %
# ADM-CFE-PROD-ED5-101
#                   Group  Number Resource  Sum_capacity  Sum_used
# 0  ADM-CFE-PROD-ED5-101       1   Memory           8.0    7.0000
# 1  ADM-CFE-PROD-ED5-101       1      CPU         800.0   33.9375
# Summary CPU
# Used 4.2421875 %
# Summary RAM
# Used 87.5 %
# Analysis for Class of hosts ADM-DB
# db101.adm.prod.ed2
# The host data is empty or host id FreeBSD OS
# db101.adm.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts API-FE
# web001.api.prod.ed1
# web002.api.prod.ed1
# web003.api.prod.ed1
# web004.api.prod.ed1
# web101.api.prod.ed1
# The host data is empty or host id FreeBSD OS
# web102.api.prod.ed1
# The host data is empty or host id FreeBSD OS
# web101.api.prod.ed2
# web102.api.prod.ed2
# web101.api.prod.ed5
# web102.api.prod.ed5
# web103.api.prod.ed5
# web104.api.prod.ed5
# The host data is empty or host id FreeBSD OS
# WEB001.API.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB002.API.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB003.API.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB004.API.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts API-HA
# ha101.api.prod.ed1
# ha102.api.prod.ed1
# ha101.api.prod.ed2
# ha102.api.prod.ed2
# ha101.api.prod.ed5
# ha102.api.prod.ed5
# Analysis for Class of hosts API-RED-CACHE
# red101.api.prod.ed1
# red102.api.prod.ed1
# red103.api.prod.ed1
# red101.api.prod.ed2
# The host data is empty or host id FreeBSD OS
# red102.api.prod.ed2
# red103.api.prod.ed2
# red101.api.prod.ed5
# The host data is empty or host id FreeBSD OS
# red102.api.prod.ed5
# red103.api.prod.ed5
# Analysis for Class of hosts COMN-BE
# be001.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be003.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be101.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be102.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be103.comn.prod.ed1
# The host data is empty or host id FreeBSD OS
# be001.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be002.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be003.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be101.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be102.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be103.comn.prod.ed2
# The host data is empty or host id FreeBSD OS
# be001.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# be002.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# be003.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# be101.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# be102.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# be103.comn.prod.ed5
# The host data is empty or host id FreeBSD OS
# BE001.COMN.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE002.COMN.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE003.COMN.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE001.COMN.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE002.COMN.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE003.COMN.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE001.COMN.PROD.ED2
# The host data is empty or host id FreeBSD OS
# BE002.COMN.PROD.ED2
# The host data is empty or host id FreeBSD OS
# BE003.COMN.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts DMZ-FTP
# ftp001.dmz.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-BACKUPDB
# backupdb001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# backupdb002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# backupdb101.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# backupdb101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-BE-APP
# app001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app006.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app009.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app010.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app011.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app012.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app013.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app014.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app015.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app016.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app007.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app008.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app102.eta.prod.ed1
# app103.eta.prod.ed1
# app104.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app105.eta.prod.ed1
# app106.eta.prod.ed1
# app107.eta.prod.ed1
# app108.eta.prod.ed1
# app109.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app110.eta.prod.ed1
# app111.eta.prod.ed1
# app112.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app007.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app106.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app107.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app108.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app109.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app110.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app111.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app112.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed5
# app102.eta.prod.ed5
# app103.eta.prod.ed5
# app104.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP006.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP004.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP007.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP008.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-BE-CUSTOM
# custom001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# ed1ag03.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1ag04.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed1
# custom102.eta.prod.ed1
# custom001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2ag06.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2ag01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2ag07.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2idp01.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# ed5ag01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5ag02.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5idp01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5idp02.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed5
# custom102.eta.prod.ed5
# CUSTOM001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM005.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM006.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-DB
# ed1db15.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1db20.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1db12.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1db17.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1db13.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1db18.etadirect.com
# The host data is empty or host id FreeBSD OS
# db001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# db002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# db003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# db004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# db005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# db101.eta.prod.ed1
# db102.eta.prod.ed1
# ed2db12.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2db15.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2db09.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2db13.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2db10.etadirect.com
# The host data is empty or host id FreeBSD OS
# db001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# db103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed5db03.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5db04.etadirect.com
# The host data is empty or host id FreeBSD OS
# db001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# db002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# db003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# db004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# db101.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# db102.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-FE
# web001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web006.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web007.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web008.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web009.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web010.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web011.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web012.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web013.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web014.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web015.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web016.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web017.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web018.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web019.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web020.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web021.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web022.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web023.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web024.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web025.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web026.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web027.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# ed1web30.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web31.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web64.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web56.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web57.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web44.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web45.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web46.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web47.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web48.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web49.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web50.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web51.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web52.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web53.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web54.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1web55.etadirect.com
# The host data is empty or host id FreeBSD OS
# web101.eta.prod.ed1
# web102.eta.prod.ed1
# web103.eta.prod.ed1
# web104.eta.prod.ed1
# web105.eta.prod.ed1
# web106.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web107.eta.prod.ed1
# web108.eta.prod.ed1
# web109.eta.prod.ed1
# web110.eta.prod.ed1
# web111.eta.prod.ed1
# web112.eta.prod.ed1
# web113.eta.prod.ed1
# web114.eta.prod.ed1
# web115.eta.prod.ed1
# web116.eta.prod.ed1
# web117.eta.prod.ed1
# web118.eta.prod.ed1
# web119.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# web001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2web27.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2web26.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2web15.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2web33.etadirect.com
# The host data is empty or host id FreeBSD OS
# web007.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web008.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web009.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web010.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web011.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web012.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web013.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web014.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web015.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web016.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web017.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web018.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web019.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web020.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web021.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web022.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web023.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web024.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web025.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web026.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web027.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web028.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web029.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web030.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web031.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web032.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web033.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web034.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web035.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web106.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web107.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web108.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web109.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web110.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web111.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web112.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web113.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web114.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web115.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web116.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web117.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web118.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web119.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# web001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web005.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web006.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# ed5web13.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5web14.etadirect.com
# The host data is empty or host id FreeBSD OS
# web101.eta.prod.ed5
# web102.eta.prod.ed5
# web103.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# web104.eta.prod.ed5
# web105.eta.prod.ed5
# web106.eta.prod.ed5
# web107.eta.prod.ed5
# web108.eta.prod.ed5
# services001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed1
# services102.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services103.eta.prod.ed1
# services104.eta.prod.ed1
# services105.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed5
# services102.eta.prod.ed5
# services103.eta.prod.ed5
# services104.eta.prod.ed5
# WEB001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB006.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB005.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB006.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB007.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB008.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB009.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB007.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB008.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB009.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB010.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB011.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB012.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB010.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB011.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB012.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB013.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB014.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB015.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB013.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB014.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB015.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# WEB016.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB003.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB004.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB005.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB006.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# WEB016.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB017.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB018.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES005.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# web120.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-FE-SERVICES
# services001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed1
# services102.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services103.eta.prod.ed1
# services104.eta.prod.ed1
# services105.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# services001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# services001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# services101.eta.prod.ed5
# services102.eta.prod.ed5
# services103.eta.prod.ed5
# services104.eta.prod.ed5
# SERVICES001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# SERVICES002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES005.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SERVICES003.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# SERVICES004.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-FS
# ed1fs03.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1fs04.etadirect.com
# The host data is empty or host id FreeBSD OS
# fs001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# fs002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# fs101.eta.prod.ed1
# fs102.eta.prod.ed1
# ed2fs02.etadirect.com
# The host data is empty or host id FreeBSD OS
# fs001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# fs002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed5fs01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5fs02.etadirect.com
# The host data is empty or host id FreeBSD OS
# fs001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# fs002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# fs101.eta.prod.ed5
# fs102.eta.prod.ed5
# Analysis for Class of hosts ETA-HA
# ha101.eta.prod.ed1
# ha102.eta.prod.ed1
# ha101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha101.eta.prod.ed5
# ha102.eta.prod.ed5
# Analysis for Class of hosts ETA-RED
# ed1cfgred01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1cfgred02.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2cfgred01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2cfgred02.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5cfgred01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5cfgred02.etadirect.com
# The host data is empty or host id FreeBSD OS
# red001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed1
# red102.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red103.eta.prod.ed1
# red001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed5
# red102.eta.prod.ed5
# red103.eta.prod.ed5
# red003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed1
# red105.eta.prod.ed1
# red106.eta.prod.ed1
# red003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red106.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed5
# red105.eta.prod.ed5
# red106.eta.prod.ed5
# RED001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED006.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED006.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-RED-HISTORY
# red001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed1
# red102.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red103.eta.prod.ed1
# red001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red101.eta.prod.ed5
# red102.eta.prod.ed5
# red103.eta.prod.ed5
# RED001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-RED-SESSION
# red003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed1
# red105.eta.prod.ed1
# red106.eta.prod.ed1
# red003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red106.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# red004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red005.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red006.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# red104.eta.prod.ed5
# red105.eta.prod.ed5
# red106.eta.prod.ed5
# RED003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# RED006.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED006.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-ST
# st001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# st002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# st101.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# st102.eta.prod.ed1
# st001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# st002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# st101.eta.prod.ed2
# Len of unique data less than number of clusters
# st102.eta.prod.ed2
# Len of unique data less than number of clusters
# st001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# st002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# st101.eta.prod.ed5
# st102.eta.prod.ed5
# Len of unique data less than number of clusters
# ST001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# ST002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# ST001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# ST002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# ST001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# ST002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# ETA-ST-PROD-ED1-101
#                  Group  Number Resource  Sum_capacity  Sum_used
# 0  ETA-ST-PROD-ED1-101       1   Memory           2.0   1.00000
# 1  ETA-ST-PROD-ED1-101       1      CPU         200.0  19.28125
# Summary CPU
# Used 9.640625 %
# Summary RAM
# Used 50.0 %
# ETA-ST-PROD-ED2-101
#                  Group  Number Resource  Sum_capacity  Sum_used
# 0  ETA-ST-PROD-ED2-101       2   Memory           4.0   2.00000
# 1  ETA-ST-PROD-ED2-101       2      CPU         400.0  19.21875
# Summary CPU
# Used 4.8046875 %
# Summary RAM
# Used 50.0 %
# ETA-ST-PROD-ED5-101
#                  Group  Number Resource  Sum_capacity  Sum_used
# 0  ETA-ST-PROD-ED5-101       2   Memory           4.0     2.000
# 1  ETA-ST-PROD-ED5-101       2      CPU         400.0   104.125
# Summary CPU
# Used 26.03125 %
# Summary RAM
# Used 50.0 %
# Analysis for Class of hosts ETAWF-BE
# be001.etawf.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.etawf.prod.ed1
# The host data is empty or host id FreeBSD OS
# be101.etawf.prod.ed1
# be102.etawf.prod.ed1
# be001.etawf.prod.ed2
# The host data is empty or host id FreeBSD OS
# be101.etawf.prod.ed2
# The host data is empty or host id FreeBSD OS
# be102.etawf.prod.ed2
# The host data is empty or host id FreeBSD OS
# be001.etawf.prod.ed5
# The host data is empty or host id FreeBSD OS
# be002.etawf.prod.ed5
# The host data is empty or host id FreeBSD OS
# be101.etawf.prod.ed5
# be102.etawf.prod.ed5
# BE001.ETAWF.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE002.ETAWF.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE001.ETAWF.PROD.ED2
# The host data is empty or host id FreeBSD OS
# BE001.ETAWF.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE002.ETAWF.PROD.ED5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts FSA-BE
# be001.fsa.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.fsa.prod.ed1
# The host data is empty or host id FreeBSD OS
# be003.fsa.prod.ed1
# The host data is empty or host id FreeBSD OS
# be004.fsa.prod.ed1
# The host data is empty or host id FreeBSD OS
# be101.fsa.prod.ed1
# be102.fsa.prod.ed1
# be103.fsa.prod.ed1
# be104.fsa.prod.ed1
# be001.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be002.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be003.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be101.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be102.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be103.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be104.fsa.prod.ed2
# The host data is empty or host id FreeBSD OS
# be001.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be002.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be003.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be004.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be101.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be102.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be103.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# be104.fsa.prod.ed5
# The host data is empty or host id FreeBSD OS
# BE001.FSA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE002.FSA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE003.FSA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE004.FSA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE001.FSA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE002.FSA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE003.FSA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE004.FSA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE001.FSA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# BE002.FSA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# BE003.FSA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts GEO-BE
# be001.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# be101.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# be102.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# be001.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# be101.geo.prod.ed2
# be102.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# be001.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# be002.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# be101.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# be102.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts GEOS-MR
# mr001.geos.prod.ed1
# The host data is empty or host id FreeBSD OS
# mr002.geos.prod.ed1
# The host data is empty or host id FreeBSD OS
# mr101.geos.prod.ed2
# The host data is empty or host id FreeBSD OS
# mr102.geos.prod.ed2
# The host data is empty or host id FreeBSD OS
# mr101.geos.prod.ed5
# The host data is empty or host id FreeBSD OS
# mr102.geos.prod.ed5
# The host data is empty or host id FreeBSD OS
# MR001.GEOS.PROD.ED1
# The host data is empty or host id FreeBSD OS
# MR002.GEOS.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LDAP-BE
# be001.ldap.prod.ed1
# The host data is empty or host id FreeBSD OS
# be001.ldap.prod.ed2
# The host data is empty or host id FreeBSD OS
# be001.ldap.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LOG-FS
# fs101.log.prod.ed1
# The host data is empty or host id FreeBSD OS
# fs101.log.prod.ed2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LP-FE
# web101.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# web102.lp.prod.ed1
# web103.lp.prod.ed1
# web101.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# web102.lp.prod.ed2
# web103.lp.prod.ed2
# web001.lp.prod.ed5
# web002.lp.prod.ed5
# web003.lp.prod.ed5
# web101.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# web102.lp.prod.ed5
# web103.lp.prod.ed5
# WEB004.LP.PROD.ED1
# The host data is empty or host id FreeBSD OS
# WEB005.LP.PROD.ED1
# The host data is empty or host id FreeBSD OS
# web104.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# web105.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# web004.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# web005.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# web104.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# web105.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# web004.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# web005.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# web104.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# web105.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LP-HA
# ha101.lp.prod.ed1
# ha102.lp.prod.ed1
# ha101.lp.prod.ed2
# ha102.lp.prod.ed2
# ha101.lp.prod.ed5
# ha102.lp.prod.ed5
# ha001.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha002.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LP-RED-CONFIG
# red001.lp.prod.ed1
# red002.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# red003.lp.prod.ed1
# red101.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# red102.lp.prod.ed1
# red103.lp.prod.ed1
# red101.lp.prod.ed2
# red102.lp.prod.ed2
# red103.lp.prod.ed2
# red001.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red002.lp.prod.ed5
# red003.lp.prod.ed5
# red101.lp.prod.ed5
# red102.lp.prod.ed5
# red103.lp.prod.ed5
# RED001.LP.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED002.LP.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED003.LP.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts MODULES-HA
# ha001.modules.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha002.modules.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha101.modules.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha102.modules.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha001.modules.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha101.modules.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha102.modules.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha001.modules.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha002.modules.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha101.modules.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha102.modules.prod.ed5
# The host data is empty or host id FreeBSD OS
# HA001.MODULES.PROD.ED1
# The host data is empty or host id FreeBSD OS
# HA002.MODULES.PROD.ED1
# The host data is empty or host id FreeBSD OS
# HA001.MODULES.PROD.ED2
# The host data is empty or host id FreeBSD OS
# HA001.MODULES.PROD.ED5
# The host data is empty or host id FreeBSD OS
# HA002.MODULES.PROD.ED5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts MON-BE
# be001.mon.prod.ed1
# The host data is empty or host id FreeBSD OS
# ed1mon02.etadirect.com
# The host data is empty or host id FreeBSD OS
# be001.mon.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2mon02.etadirect.com
# The host data is empty or host id FreeBSD OS
# be001.mon.prod.ed5
# The host data is empty or host id FreeBSD OS
# ed5mon02.etadirect.com
# ...
# The host data is empty or host id FreeBSD OS
# fe006.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe007.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe101.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe102.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe103.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe104.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# fe105.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# FE001.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE002.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE003.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE001.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE002.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE003.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE004.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE005.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE006.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE001.SC.PROD.ED5
# The host data is empty or host id FreeBSD OS
# FE002.SC.PROD.ED5
# The host data is empty or host id FreeBSD OS
# FE003.SC.PROD.ED5
# The host data is empty or host id FreeBSD OS
# FE007.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE008.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE009.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE010.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE019.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE020.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE021.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE022.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE023.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE024.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE025.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE026.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE027.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE028.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE103.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE104.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE105.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE106.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE107.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE108.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# FE106.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE107.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# FE108.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts SC-HA
# ha001.sc.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha002.sc.prod.ed1
# The host data is empty or host id FreeBSD OS
# ed1cmnlb01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ha101.sc.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha102.sc.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha001.sc.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha002.sc.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2cmnlb01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ha101.sc.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha102.sc.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha001.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha002.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha101.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha102.sc.prod.ed5
# The host data is empty or host id FreeBSD OS
# HA001.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# HA002.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# HA001.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# HA002.SC.PROD.ED2
# The host data is empty or host id FreeBSD OS
# HA001.SC.PROD.ED5
# The host data is empty or host id FreeBSD OS
# HA002.SC.PROD.ED5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts SL-BE
# be001.sl.prod.ed1
# The host data is empty or host id FreeBSD OS
# be002.sl.prod.ed1
# The host data is empty or host id FreeBSD OS
# be101.sl.prod.ed1
# Len of unique data less than number of clusters
# be102.sl.prod.ed1
# be103.sl.prod.ed1
# be001.sl.prod.ed2
# The host data is empty or host id FreeBSD OS
# be101.sl.prod.ed2
# be102.sl.prod.ed2
# be103.sl.prod.ed2
# be001.sl.prod.ed5
# The host data is empty or host id FreeBSD OS
# be002.sl.prod.ed5
# The host data is empty or host id FreeBSD OS
# be101.sl.prod.ed5
# be102.sl.prod.ed5
# be103.sl.prod.ed5
# BE001.SL.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE002.SL.PROD.ED5
# The host data is empty or host id FreeBSD OS
# BE001.SL.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE002.SL.PROD.ED1
# The host data is empty or host id FreeBSD OS
# BE001.SL.PROD.ED2
# The host data is empty or host id FreeBSD OS
# SL-BE-PROD-ED1-101
#                 Group  Number Resource  Sum_capacity  Sum_used
# 0  SL-BE-PROD-ED1-101       1   Memory          63.0     25.00
# 1  SL-BE-PROD-ED1-101       1      CPU         400.0    121.75
# Summary CPU
# Used 30.4375 %
# Summary RAM
# Used 39.6728515625 %
# Analysis for Class of hosts SL-DB
# db101.sl.prod.ed1
# db102.sl.prod.ed1
# db101.sl.prod.ed2
# db102.sl.prod.ed2
# db101.sl.prod.ed5
# db102.sl.prod.ed5
# Analysis for Class of hosts THRUK-SRV
# srv001.thruk.prod.ed1
# The host data is empty or host id FreeBSD OS
# SRV001.THRUK.PROD.ED1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ETA-BE
# app001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app005.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app006.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app009.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app010.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app011.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app012.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app013.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app014.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app015.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app016.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app007.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app008.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app102.eta.prod.ed1
# app103.eta.prod.ed1
# app104.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app105.eta.prod.ed1
# app106.eta.prod.ed1
# app107.eta.prod.ed1
# app108.eta.prod.ed1
# app109.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app110.eta.prod.ed1
# app111.eta.prod.ed1
# app112.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# app001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app007.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app103.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app104.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app105.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app106.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app107.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app108.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app109.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app110.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app111.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app112.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# app001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app003.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app004.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# app101.eta.prod.ed5
# app102.eta.prod.ed5
# app103.eta.prod.ed5
# app104.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# custom001.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# ed1ag03.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed1ag04.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom003.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom004.eta.prod.ed1
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed1
# custom102.eta.prod.ed1
# custom001.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2ag06.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2ag01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2ag07.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom003.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom004.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# ed2idp01.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom005.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom006.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom102.eta.prod.ed2
# The host data is empty or host id FreeBSD OS
# custom001.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# custom002.eta.prod.ed5
# The host data is empty or host id FreeBSD OS
# ed5ag01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5ag02.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5idp01.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5idp02.etadirect.com
# The host data is empty or host id FreeBSD OS
# custom101.eta.prod.ed5
# custom102.eta.prod.ed5
# ed1srv47.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2srv27.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2srv33.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed2srv30.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5srv10.etadirect.com
# The host data is empty or host id FreeBSD OS
# ed5srv09.etadirect.com
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM001.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM002.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM001.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM002.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# APP001.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP002.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP005.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP006.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP003.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP004.ETA.PROD.ED5
# The host data is empty or host id FreeBSD OS
# APP007.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# APP008.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM003.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM004.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM003.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM004.ETA.PROD.ED1
# The host data is empty or host id FreeBSD OS
# CUSTOM005.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# CUSTOM006.ETA.PROD.ED2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts GEO-DB
# db101.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# db102.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# db101.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# db102.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# db101.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# db102.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts GEO-HA
# ha101.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha102.geo.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha101.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha102.geo.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha101.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha102.geo.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts GEOS-DB
# db101.geos.prod.ed1
# The host data is empty or host id FreeBSD OS
# db102.geos.prod.ed1
# The host data is empty or host id FreeBSD OS
# db101.geos.prod.ed2
# The host data is empty or host id FreeBSD OS
# db102.geos.prod.ed2
# The host data is empty or host id FreeBSD OS
# db101.geos.prod.ed5
# The host data is empty or host id FreeBSD OS
# db102.geos.prod.ed5
# The host data is empty or host id FreeBSD OS
# DB001.GEOS.PROD.ED5
# The host data is empty or host id FreeBSD OS
# DB002.GEOS.PROD.ED5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LOG-DB
# db101.log.prod.ed1
# The host data is empty or host id FreeBSD OS
# db001.log.prod.ed2
# The host data is empty or host id FreeBSD OS
# db101.log.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts LP-RED-AUTH
# red104.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# red106.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# red105.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# red104.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# red105.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# red106.lp.prod.ed2
# The host data is empty or host id FreeBSD OS
# red004.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red005.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red006.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red104.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red105.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red106.lp.prod.ed5
# The host data is empty or host id FreeBSD OS
# red004.lp.prod.ed1
# red005.lp.prod.ed1
# red006.lp.prod.ed1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts OFFLINEBACKUP-DB
# db101.offlinebackup.prod.ed2
# The host data is empty or host id FreeBSD OS
# db102.offlinebackup.prod.ed2
# The host data is empty or host id FreeBSD OS
# db103.offlinebackup.prod.ed2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts SL-HA
# ha101.sl.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha102.sl.prod.ed1
# The host data is empty or host id FreeBSD OS
# ha101.sl.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha102.sl.prod.ed2
# The host data is empty or host id FreeBSD OS
# ha101.sl.prod.ed5
# The host data is empty or host id FreeBSD OS
# ha102.sl.prod.ed5
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts BOND-DB
# db101.bond.prod.ed2
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts ELK-MR
# mr102.elk.prod.ed1
# The host data is empty or host id FreeBSD OS
# Analysis for Class of hosts SC-RED
# RED101.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED102.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS
# RED103.SC.PROD.ED1
# The host data is empty or host id FreeBSD OS

# %%
Sclass=Classes[1]
NET='PROD'
start=str(Input_D.index[0])
end=str(Input_D.index[1])

# %%
Ds=D[D.Group.str.contains(NET)]
Ds=Ds[Ds.Group.str.contains(Sclass)]
DF=pd.DataFrame()
print('Analysis for Class of hosts '+Sclass)
for host in Ds['server']:
    print host
    #r=get_host_data (host, user, password)
    #if r==0:
    #    continue
    #get_resource_tables(path+host)
    if host in os.listdir(path):
        R=forecast_on_sar(host, user, path=path, start=start, end=end, plot_clust=False)
        DF=DF.append(R)
    else:
        print('The host data is empty or host id FreeBSD OS')
# Out:
# Analysis for Class of hosts ADM-BE

# %%
# %run load_forecast.py
DFR_CPU=pd.DataFrame()
DFR_RAM=pd.DataFrame()
for h in DF.index.unique():
    d=DF.loc[h]
    d=d[d['Param'].str.contains('real_used')]
    d=d[d.Used==max(d.Used)]
    DFR_RAM=DFR_RAM.append(d)
    d=DF.loc[h]
    d=d[d['Param']=='used_cpu']
    DFR_CPU=DFR_CPU.append(d)
DFR_RAM['server']=DFR_RAM.index.values
DFR_CPU['server']=DFR_CPU.index.values
DFR_RAM['Available']=[np.round(np.float16(DFR_RAM.loc[i]['Capacity'])-np.float16(DFR_RAM.loc[i]['Used']),2) \
                      for i in DFR_RAM.index]
DFR_CPU['Available']=[np.round(np.float16(DFR_CPU.loc[i]['Capacity'])*100-np.float16(DFR_CPU.loc[i]['Used'].replace(' %', '')),2) \
                      for i in DFR_CPU.index]
DFR_CPU=pd.merge(DFR_CPU, D)
DFR_RAM=pd.merge(DFR_RAM, D)
F=get_resource_data(Sclass,DFR_RAM=DFR_RAM, DFR_CPU=DFR_CPU)

# %%
RES['Users']=[np.nan]*RES.shape[0]
for i in RES.index:
    if 'ED1' in RES.ix[i]['Server_class']:
        RES.loc[i,'Users']=Input_D.MIA_users[0]
    elif 'ED5' in RES.ix[i]['Server_class']:
        RES.loc[i,'Users']=Input_D.MAD_users[0]
RES=RES.dropna(axis=0)

RES.to_csv(path+Sclass+str(datetime.datetime.now())+".csv")

# %%
path
# Out:
# '/Users/annachystiakova/Documents/Capacity/sar_analysis/sar_data/'

# %%
# %run plot_class_data.py
DFR_CPU_d=DFR_CPU[['Capacity', 'Details', 'Resource','Used', 'server', 'Available']]
DFR_CPU_d.columns=['Capacity_cpu', 'Details_cpu', 'Resource','Used_cpu', 'server', 'Available_cpu']
DFR_RAM_d=DFR_RAM[['Capacity', 'Details', 'Resource','Used', 'server', 'Available', 'Group']]
DFR_RAM_d.columns=['Capacity_mem', 'Details_mem', 'Resource','Used_mem', 'server', 'Available_mem', 'Group']
D=DFR_CPU_d.merge(DFR_RAM_d, on='server')
RES=pd.DataFrame()
for G in D.Group.unique():
    d=D[D.Group==G]
    d['util_mem']=100*d['Used_mem']/d['Capacity_mem']
    d['util_cpu']=[np.float16(x.replace(' %','')) for x in d['Used_cpu']]
    
    min_util_mem=min(d['util_mem'])
    max_util_mem=max(d['util_mem'])
    avg_util_mem=100*(sum(d['Used_mem'])/sum(d['Capacity_mem']))
    sum_utilized_mem=sum(d['Used_mem'])
    s=d['Capacity_mem'].unique()
    mem_per_fost=','.join(str(x) for x in s )
    
    min_util_cpu=min(d['util_cpu'])
    max_util_cpu=max(d['util_cpu'])
    avg_util_cpu=100*(sum(d['util_cpu'])/sum(100*d['Capacity_cpu']))
    sum_utilized_cpu=sum(d['util_cpu'])
    s1=d['Capacity_cpu'].unique()
    cpu_per_fost=','.join(str(x) for x in s1 )
    RES=RES.append({'Server_class':G, 'Number_of_hosts':d.shape[0],'Mem_min_utilized':min_util_mem, \
                    'Mem_max_utilized':max_util_mem, 'Mem_avg_clust':avg_util_mem, 'Config_mem':mem_per_fost,\
                    'Mem_Sum_utilized': sum_utilized_mem,\
                   'CPU_min_utilized':min_util_cpu, \
                    'CPU_max_utilized':max_util_cpu, 'CPU_avg_clust':avg_util_cpu, 'Config_cpu':cpu_per_fost,\
                    'CPU_Sum_utilized': sum_utilized_cpu},ignore_index=True)
plot_data(RES)
# Out:
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/annachystiakova/py_envs/venv/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Billing=pd.read_csv(leter_path+"result.csv", sep=';')
Billing=Billing[Billing.Date<=end]
Billing=Billing[Billing.Date==max(Billing.Date)]
Billing.users_number.sum()
MIA_Users=Billing[Billing.DC=='ed1'].users_number.sum()
MAD_Users=Billing[Billing.DC=='ed5'].users_number.sum()
CMDB=pd.read_excel(source_path+"Companies_16_2.xlsx", sheetname='All_CMDB')
CMDB=CMDB[['Instance ID','Instance Name','BE Master','Version']]
CMDB.columns=['Instance ID','Company','BE Master','Version']
#To resolve the inconsistencies in CMDB and Weekly reports (Company names)
Billing.loc[Billing.Company=='tim','Company']='timcelular'
list(set(CMDB.Company.values) - set(Billing.Company.values))

# %%
import warnings
year=datetime.datetime.strptime(end[:10],"%Y-%m-%d").year
month=datetime.datetime.strptime(end[:10],"%Y-%m-%d").month
Month_bil=pd.read_excel(source_path+"Active_users_for_all_companies.xlsx", sheetname=str(year))
import calendar
Month_bil=Month_bil.dropna(axis=1, how='all')
#print(Month_bil.loc[Month_bil['Company'] == 'INACTIVE'].index.tolist()[0])
Month_bil=(Month_bil[0:Month_bil.loc[Month_bil['Company'] == 'INACTIVE'].index.tolist()[0]])
#Month_bil.ix((Month_bil.iloc(Month_bil.Company=='INACTIVE'))))
MD=dict((v,k) for k,v in enumerate(calendar.month_abbr))
Month_bil.columns=[MD[x] if x!='Company' else x for x in Month_bil.columns ]
Month_bil=Month_bil[['Company']+[x for x in Month_bil.columns if x!='Company' and x<=month]]
Month_bil['Company']=Month_bil['Company'].str.lower()
MM=max([x for x in Month_bil.columns if x!='Company'])
Month_bil=Month_bil[['Company', MM]]
Month_bil=Month_bil.dropna(axis=0, how='any')

CMDB_Companies=pd.read_excel(source_path+"Companies_16_2.xlsx", sheetname=str('All_CMDB'))
CMDB_Companies=CMDB_Companies[['Instance ID','Instance Name','BE Master','Version']]
CMDB_Companies.rename(columns={'Instance ID': 'Instance ID', 'Instance Name': 'Company', 'BE Master':'BE Master','Version':'Version'}, inplace=True)

CMDB_Companies['Company'].replace([u'musmrs',u'vm2', u'amx-res-cenam', u'cbv', u'vodafone', u'amx-res-co',u'lm',u'kiercorporate'],[ u'mus',u'virginmedia', u'amx-cenam', u'cablevision', u'vodafone-spain',u'amx-colombia', u'liberty',u'kierutilities'],inplace=True)


Comp_Users=CMDB_Companies.merge(Month_bil, on=['Company'])
DIF=(list(set(Month_bil.Company)-set(CMDB_Companies.Company)))
#print'Difference in company names from billing and CMDB !!!',','.join(DIF)
if (len(DIF)>0):
    msg='Difference in company names from billing and CMDB !!!',','.join(DIF)
    #warnings.warn(msg)
    print(msg)
#print(list(set(CMDB_Companies.Company)-set(Month_bil.Company)))
MIA_users_16_2=Comp_Users[Comp_Users['BE Master'].str.contains('ed1')]
MIA_users_16_2=MIA_users_16_2[MIA_users_16_2['Version'].str.contains('platform-16.2.')]
print('Sum number of users in ED1 version 16.2')
print(MIA_users_16_2[6].sum())

MAD_users_16_2=Comp_Users[Comp_Users['BE Master'].str.contains('ed5')]
MAD_users_16_2=MAD_users_16_2[MAD_users_16_2['Version'].str.contains('platform-16.2.')]
print('Sum number of users in ED1 version 16.2')
print(MAD_users_16_2[6].sum())

RES['Users']=[np.nan]*RES.shape[0]
for i in RES.index:
    if 'ED1' in RES.ix[i]['Server_class']:
        RES.loc[i,'Users']=MIA_users_16_2[6].sum()
    elif 'ED5' in RES.ix[i]['Server_class']:
        RES.loc[i,'Users']=MAD_users_16_2[6].sum() 
RES=RES.dropna(axis=0)
RES.head()
# Out:
# ('Difference in company names from billing and CMDB !!!', u'lsnewco')
# Sum number of users in ED1 version 16.2
# 26544.0
# Sum number of users in ED1 version 16.2
# 13916.0
#    CPU_Sum_utilized  CPU_avg_clust  CPU_max_utilized  CPU_min_utilized  \
# 0         11.250000       5.625000          11.25000         11.250000
# 2         14.410156       3.602539           9.46875          4.941406
#
#   Config_cpu Config_mem  Mem_Sum_utilized  Mem_avg_clust  Mem_max_utilized  \
# 0        2.0        2.0               1.0           50.0              50.0
# 2        2.0        2.0               2.0           50.0              50.0
#
#    Mem_min_utilized  Number_of_hosts         Server_class    Users
# 0              50.0              1.0  ETA-ST-PROD-ED1-101  26544.0
# 2              50.0              2.0  ETA-ST-PROD-ED5-101  13916.0

# %%
classes=np.unique([x.split('-ED')[0] for x in RES.Server_class])
Class_Models_Mem=pd.DataFrame()
Class_Models_CPU=pd.DataFrame()
for C in classes:
    #print(C)
    d=RES[RES.Server_class.str.contains(C)]
    d=d[['Mem_Sum_utilized','Config_mem', 'Users', 'Number_of_hosts']]
    #plt.plot(d['Users'], d['Mem_Sum_utilized'])
    lm=LinearRegression()
    lm.fit(d['Users'].reshape(len(d['Users']),1), d['Mem_Sum_utilized'])
    s=d.Config_mem.unique()
    s=(','.join(str(x) for x in s )).split(',')
    s=np.unique([np.float16(x) for x in s])
    s1=','.join(str(x) for x in s )
    Class_Models_Mem=Class_Models_Mem.append({'Class':C,'mem_a':lm.coef_[0],'mem_b':lm.intercept_, 'Analysed mem config':s1,'Planned mem config':max(s),'Min_number of hosts':min(d['Number_of_hosts'])}, ignore_index=True)
    
    d=RES[RES.Server_class.str.contains(C)]
    d=d[['CPU_Sum_utilized','Config_cpu', 'Users', 'Number_of_hosts']]
    #plt.plot(d['Users'], d['CPU_Sum_utilized'])
    lm=LinearRegression()
    lm.fit(d['Users'].reshape(len(d['Users']),1), d['CPU_Sum_utilized'])
    s=d.Config_cpu.unique()
    s=(','.join(str(x) for x in s )).split(',')
    s=np.unique([np.float16(x) for x in s])
    s=','.join(str(x) for x in s )
    Class_Models_CPU=Class_Models_CPU.append({'Class':C,'cpu_a':lm.coef_[0],'cpu_b':lm.intercept_, 'Analysed cpu config':s,'Min_number of hosts':min(d['Number_of_hosts'])}, ignore_index=True)
Class_Models=Class_Models_Mem.merge(Class_Models_CPU, left_on=['Class','Min_number of hosts'], right_on=['Class','Min_number of hosts'], how='inner')

# %%
Class_Models
# Out:
#   Analysed mem config        Class  Min_number of hosts  Planned mem config  \
# 0                 2.0  ETA-ST-PROD                  1.0                 2.0
#
#       mem_a     mem_b Analysed cpu config    cpu_a      cpu_b
# 0 -0.000079  3.101996                 2.0 -0.00025  17.892634
